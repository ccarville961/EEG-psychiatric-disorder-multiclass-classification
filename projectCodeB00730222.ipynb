# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import mne
from math import ceil
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 4>()
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
# ----> 4 import mne
#       5 from math import ceil
#
# ModuleNotFoundError: No module named 'mne'

# %%
chs = {'FP1': [-0.03, 0.08],
       'FP2': [0.03, 0.08],
       'F7': [-0.073, 0.047],
       'F3': [-0.04, 0.041],
       'Fz': [0, 0.038],
       'F4': [0.04, 0.041],
       'F8': [0.073, 0.047],
       'T3': [-0.085, 0],
       'C3': [-0.045, 0],
       'Cz': [0, 0],
       'C4': [0.045, 0],
       'T4': [0.085, 0],
       'T5': [-0.073, -0.047],
       'P3': [-0.04, -0.041],
       'Pz': [0, -0.038],
       'P4': [0.04, -0.041],
       'T6': [0.07, -0.047],
       'O1': [-0.03, -0.08],
       'O2': [0.03, -0.08]}
channels = pd.DataFrame(chs).transpose()
channels

# %%
mont = mne.channels.make_dig_montage(chs)
mont.plot()
plt.show()

# %%
df = pd.read_csv('eegData/eegDatasetCleaned.csv')
df
# Out:
#          specific.disorder  AB.A.delta.a.FP1  AB.A.delta.b.FP2  \
# 0      acuteStressDisorder         30.323572         29.558049
# 1      acuteStressDisorder         23.327612         34.845856
# 2      acuteStressDisorder         17.252066         15.155292
# 3      acuteStressDisorder         34.912317         39.136562
# 4      acuteStressDisorder          8.520262          9.073504
# ..                     ...               ...               ...
# 940  socialAnxietyDisorder         17.585491         16.912154
# 941  socialAnxietyDisorder         21.393045         23.018120
# 942  socialAnxietyDisorder         19.543898         18.035856
# 943  socialAnxietyDisorder         11.581630         16.528605
# 944  socialAnxietyDisorder         43.770838         41.406970
#
#      AB.A.delta.c.F7  AB.A.delta.d.F3  AB.A.delta.e.Fz  AB.A.delta.f.F4  \
# 0          25.293659        25.431386        27.157943        26.064096
# ...
